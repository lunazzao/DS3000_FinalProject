# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import plotly.express as px

# %%
features = pd.read_csv("res/features.csv")
features.set_index("MAL_ID", inplace=True)
features.head()
# Out:
#         Episodes  Duration  Members  Genres_Action  Genres_Adventure  \
# MAL_ID
# 1           26.0      24.0  1251960              1                 1
# 5            1.0     115.0   273145              1                 0
# 6           26.0      24.0   558913              1                 1
# 7           26.0      25.0    94683              1                 0
# 8           52.0      23.0    13224              0                 1
#
#         Genres_Cars  Genres_Comedy  Genres_Dementia  Genres_Demons  \
# MAL_ID
# 1                 0              1                0              0
# 5                 0              0                0              0
# 6                 0              1                0              0
# 7                 0              0                0              0
# 8                 0              0                0              0
#
#         Genres_Drama  ...  Source_Visual novel  Source_Web manga  Rating_G  \
# MAL_ID                ...
# ...

# %%
target = pd.read_csv("res/popularity.csv")
target.set_index("MAL_ID", inplace=True)
target
# Out:
#         Popularity
# MAL_ID
# 1               39
# 5              518
# 6              201
# 7             1467
# 8             4369
# ...            ...
# 48481        13116
# 48483        17562
# 48488        17558
# 48491        17565
# 48492        17563
#
# [17562 rows x 1 columns]

# %%
#PCA Visualization
pca = PCA(n_components= 2, random_state=3000)
features_standardized = StandardScaler().fit_transform(features)
reduced_data = pca.fit_transform(features_standardized)
reduced_df = pd.DataFrame(reduced_data, columns = ["Component1", "Component2"])
reduced_df["target"] = target["Popularity"]

reduced_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-bb8f33deaed8> in <module>
#       1 #PCA Visualization
#       2 pca = PCA(n_components= 2, random_state=3000)
# ----> 3 features_standardized = StandardScaler().fit_transform(features)
#       4 reduced_data = pca.fit_transform(features_standardized)
#       5 reduced_df = pd.DataFrame(reduced_data, columns = ["Component1", "Component2"])
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     845         if y is None:
#     846             # fit method of arity 1 (unsupervised transformation)
# --> 847             return self.fit(X, **fit_params).transform(X)
#     848         else:
#     849             # fit method of arity 2 (supervised transformation)
#
# ...

# %%
graph = px.scatter(reduced_df, x="Component1", y="Component2", color = "target")
graph.show()
